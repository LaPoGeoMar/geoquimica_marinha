# %%
import numpy as np  # Importa o pacote numérico.
import matplotlib.pyplot as plt  # Importa o pacote de plotagem (pyplot->submodulo do matplotlib)
import pandas as pd  #Pandas=biblioteca para análise e estrutura de dados

# %matplotlib inline

# %%
#df = pd.read_table("Dados_Geoquimica2022.xlsx")

#df = pd.read_excel("Dados_Geoquimica2022.xlsx") #- não consegui fazer funcionar 

kw = dict(skiprows=1, na_values='NaN', sep=',',
          skipinitialspace=True, index_col=False)


df = pd.read_csv('Dados_Geoquimica2022.csv', **kw)
df.index = make_index(df)


df
# Out:
#    Sample    CO1_%C  CO1_d13C  CO1_%N  CO1_d15N    CO1_C/N  CO2_%C  CO2_d13C  \
# 1   CO.01  2.315255    -24.85    0.22      5.07  10.523887    1.43    -23.14
# 2   CO.02       NaN    -25.27     NaN       NaN        NaN     NaN       NaN
# 3   CO.03  2.153180    -25.32    0.21      5.45  10.253236    1.27    -23.92
# 4   CO.04       NaN    -25.45     NaN       NaN        NaN     NaN       NaN
# 5   CO.05  2.483969    -25.36    0.22      5.22  11.290767    1.61    -23.23
# 6   CO.06       NaN    -25.52     NaN       NaN        NaN     NaN       NaN
# 7   CO.07  2.493050    -25.29    0.21      5.22  11.871666    1.54    -23.23
# 8   CO.08       NaN    -25.44     NaN       NaN        NaN     NaN       NaN
# 9   CO.09       NaN    -25.58     NaN       NaN        NaN     NaN       NaN
# 10  CO.10  2.167756    -25.30    0.19      4.86  11.409243    1.65    -23.10
# 11  CO.11       NaN    -25.71     NaN       NaN        NaN     NaN       NaN
# ...

# %%
#Não lembro mais porque fizemos isso - preciso manter?

def make_index(df):
    return [int(idx.split('.')[1]) for idx
            in df['Sample']]

# %%
#REVER - a ideia é fazer um gráfico de barras com uma das colunas de dados

# criar gráficos de barra com os valores encontrados
#Matplotlib


#para o gráfico aparecer logo abaixo é preciso do comando:
# %matplotlib inline

#para criar o gráfico
df["BCF"].plot.bar();
